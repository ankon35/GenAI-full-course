# %% [markdown]
# Load Env Variable

# %%
from dotenv import load_dotenv
load_dotenv()

# %%
import os

# %% [markdown]
# Connect with Open AI

# %%
from langchain_openai import ChatOpenAI
llm = ChatOpenAI(model_name="gpt-3.5-turbo", temperature=0)

# %%
res = llm.invoke("Who is the prime minister of Bangladesh?")
print(res.content)

# %% [markdown]
# Connect with Gemini

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
llm = ChatGoogleGenerativeAI(model="gemini-2.5-flash-lite", temperature=0)

# %%
res = llm.invoke("What is LangChain?")
print(res.content)

# %% [markdown]
# Static Prompts

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
llm = ChatGoogleGenerativeAI(model="gemini-2.5-flash-lite", temperature=0)

# %%
prompts = [
    ("system", "You are a python developer"),
    ("user", "How to sort an array?")
]
res = llm.invoke(prompts)
print(res.content)

# %%
from langchain_openai import ChatOpenAI
llm = ChatOpenAI(model_name="gpt-3.5-turbo", temperature=0)

# %%
prompts = [
    "system", "Act as a you are professional Java Developer"
    "User", "How to create a class in Java?"
]

res = llm.invoke(prompts)
print(res.content)
